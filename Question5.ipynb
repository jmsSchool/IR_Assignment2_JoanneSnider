# %% [markdown]
# Question 5

# %%
# - - - - - - - - - - - - - - - - - - - - - - - - - - - 
# Section 1 of 2 - Execute first to load scipy
# - - - - - - - - - - - - - - - - - - - - - - - - - - -

# !pip install scipy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# - - - - - - - - - - - - - - - - - - - - - - - - - - - 
# Section 2 of 2 - Execute second to run the program
# - - - - - - - - - - - - - - - - - - - - - - - - - - -

from scipy import stats

x1 = [0.2811, 0.4829, 0.0237, 0.4196, 0.3857, 0.2432, 0.6103, 0.4339, 0.1003, 0.0854, 0.8640]
x2 = [0.1883, 0.2974, 0.0039, 0.2403, 0.2390, 0.1390, 0.3566, 0.1818, 0.0584, 0.0519, 0.5479]

tau, p_value = stats.kendalltau(x1, x2)
print(tau, p_value)
# Out:
# 0.8909090909090909 1.3728555395222063e-05
